# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# %%
...
 
# load the dataset, split into input (X) and output (y) variables
dataset = np.loadtxt('pima-indians-diabetes.data.csv', delimiter=',')
X = dataset[:,0:8]
y = dataset[:,8]

# %%
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# %%
class PimaClassifier(nn.Module):
    def __init__(self):
        super().__init__()

        self.net = nn.Sequential(
            nn.Linear(8, 12),
            nn.ReLU(),
            nn.Linear(12, 8),
            nn.ReLU(),
            nn.Linear(8, 1),
            nn.Sigmoid()
        )
    def forward(self, x):
        return self.net(x)

# %%
model = PimaClassifier()
print(model)
# Out:
# PimaClassifier(
#   (net): Sequential(
#     (0): Linear(in_features=8, out_features=12, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=12, out_features=8, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=8, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
# )

# %%
loss_fn = nn.BCELoss()  # binary cross entropy
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
n_epochs = 100
batch_size = 10

for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        y_pred = model(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')
# Out:
# Finished epoch 0, latest loss 0.47733166813850403
# Finished epoch 1, latest loss 0.4438662827014923
# Finished epoch 2, latest loss 0.43058013916015625
# Finished epoch 3, latest loss 0.4196556806564331
# Finished epoch 4, latest loss 0.4164438843727112
# Finished epoch 5, latest loss 0.40994980931282043
# Finished epoch 6, latest loss 0.4044547975063324
# Finished epoch 7, latest loss 0.40139758586883545
# Finished epoch 8, latest loss 0.40322092175483704
# Finished epoch 9, latest loss 0.3979705572128296
# Finished epoch 10, latest loss 0.39820554852485657
# Finished epoch 11, latest loss 0.3960724472999573
# Finished epoch 12, latest loss 0.3965974450111389
# Finished epoch 13, latest loss 0.3971850574016571
# Finished epoch 14, latest loss 0.3981887698173523
# Finished epoch 15, latest loss 0.39929863810539246
# Finished epoch 16, latest loss 0.40133729577064514
# Finished epoch 17, latest loss 0.40258657932281494
# Finished epoch 18, latest loss 0.4044644832611084
# Finished epoch 19, latest loss 0.40589427947998047
# Finished epoch 20, latest loss 0.40623733401298523
# Finished epoch 21, latest loss 0.4072757959365845
# Finished epoch 22, latest loss 0.41043344140052795
# Finished epoch 23, latest loss 0.41338181495666504
# Finished epoch 24, latest loss 0.4163181781768799
# Finished epoch 25, latest loss 0.4150311052799225
# Finished epoch 26, latest loss 0.4218149781227112
# Finished epoch 27, latest loss 0.4220050871372223
# Finished epoch 28, latest loss 0.42115333676338196
# Finished epoch 29, latest loss 0.4194222390651703
# Finished epoch 30, latest loss 0.42564040422439575
# Finished epoch 31, latest loss 0.4230722188949585
# Finished epoch 32, latest loss 0.4214474558830261
# Finished epoch 33, latest loss 0.42167505621910095
# Finished epoch 34, latest loss 0.417273610830307
# Finished epoch 35, latest loss 0.4178212285041809
# Finished epoch 36, latest loss 0.41663581132888794
# Finished epoch 37, latest loss 0.42098626494407654
# Finished epoch 38, latest loss 0.4207083582878113
# Finished epoch 39, latest loss 0.41716620326042175
# Finished epoch 40, latest loss 0.419664204120636
# Finished epoch 41, latest loss 0.4179483652114868
# Finished epoch 42, latest loss 0.4181312024593353
# Finished epoch 43, latest loss 0.4175468683242798
# Finished epoch 44, latest loss 0.4205724895000458
# Finished epoch 45, latest loss 0.42276617884635925
# Finished epoch 46, latest loss 0.42204007506370544
# Finished epoch 47, latest loss 0.4216368794441223
# Finished epoch 48, latest loss 0.4227541983127594
# Finished epoch 49, latest loss 0.4205585718154907
# Finished epoch 50, latest loss 0.42046648263931274
# Finished epoch 51, latest loss 0.42150428891181946
# Finished epoch 52, latest loss 0.41920551657676697
# Finished epoch 53, latest loss 0.42306795716285706
# Finished epoch 54, latest loss 0.4222208261489868
# Finished epoch 55, latest loss 0.420303076505661
# Finished epoch 56, latest loss 0.4219513535499573
# Finished epoch 57, latest loss 0.421646386384964
# Finished epoch 58, latest loss 0.4215223491191864
# Finished epoch 59, latest loss 0.4209752678871155
# Finished epoch 60, latest loss 0.4219895303249359
# Finished epoch 61, latest loss 0.4220481514930725
# Finished epoch 62, latest loss 0.42568862438201904
# Finished epoch 63, latest loss 0.42214128375053406
# Finished epoch 64, latest loss 0.4209003448486328
# Finished epoch 65, latest loss 0.4223811626434326
# Finished epoch 66, latest loss 0.4230402410030365
# Finished epoch 67, latest loss 0.41887491941452026
# Finished epoch 68, latest loss 0.4231729805469513
# Finished epoch 69, latest loss 0.4196986258029938
# Finished epoch 70, latest loss 0.4185667335987091
# Finished epoch 71, latest loss 0.41565507650375366
# Finished epoch 72, latest loss 0.4204893112182617
# Finished epoch 73, latest loss 0.4174116551876068
# Finished epoch 74, latest loss 0.4247550964355469
# Finished epoch 75, latest loss 0.4194941818714142
# Finished epoch 76, latest loss 0.41808560490608215
# Finished epoch 77, latest loss 0.41365987062454224
# Finished epoch 78, latest loss 0.41801196336746216
# Finished epoch 79, latest loss 0.41786205768585205
# Finished epoch 80, latest loss 0.4194822907447815
# Finished epoch 81, latest loss 0.41706979274749756
# Finished epoch 82, latest loss 0.4164007008075714
# Finished epoch 83, latest loss 0.40725046396255493
# Finished epoch 84, latest loss 0.40126916766166687
# Finished epoch 85, latest loss 0.4084378778934479
# Finished epoch 86, latest loss 0.4019932150840759
# Finished epoch 87, latest loss 0.4005131721496582
# Finished epoch 88, latest loss 0.39282697439193726
# Finished epoch 89, latest loss 0.40163788199424744
# Finished epoch 90, latest loss 0.3997815251350403
# Finished epoch 91, latest loss 0.3954728841781616
# Finished epoch 92, latest loss 0.3885513246059418
# Finished epoch 93, latest loss 0.3864438831806183
# Finished epoch 94, latest loss 0.385307639837265
# Finished epoch 95, latest loss 0.3851143717765808
# Finished epoch 96, latest loss 0.38704952597618103
# Finished epoch 97, latest loss 0.3821018636226654
# Finished epoch 98, latest loss 0.3788491189479828
# Finished epoch 99, latest loss 0.38028255105018616

# %%
# compute accuracy (no_grad is optional)
with torch.no_grad():
    y_pred = model(X)

accuracy = (y_pred.round() == y).float().mean()
print(f"Accuracy {accuracy}")
# Out:
# Accuracy 0.76171875

# %%
predictions = (model(X) > 0.5).int()
for i in range(5):
    print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.599998474121094, 0.6269999742507935, 50.0] => 1 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.600000381469727, 0.35100001096725464, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.299999237060547, 0.671999990940094, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.100000381469727, 0.16699999570846558, 21.0] => 0 (expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.099998474121094, 2.2880001068115234, 33.0] => 1 (expected 1)
